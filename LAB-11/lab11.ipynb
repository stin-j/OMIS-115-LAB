# %% [markdown]
# # General Preamble Code

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import time
from IPython.display import display
#from sentence_transformers import SentenceTransformer
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Users/fustin/miniconda/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Users/fustin/miniconda/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/fustin/miniconda/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
# ...

# %% [markdown]
# # Dataset Import

# %%
# This dictionary contains the 50 headlines, theirURL
headline_data = {
    1: {'headline': 'Network suspected of smuggling 40,000 stolen phones from UK to China', 'url': 'https://news.met.police.uk/news/met-dismantles-suspected-smuggling-gang-in-uks-largest-phone-theft-crackdown-501804'},
    2: {'headline': 'Elon Musk\'s xAI Raises $10 Billion at $200 Billion Valuation', 'url': 'https://www.reuters.com/technology/elon-musks-xai-raises-10-billion-200-billion-valuation-report-2025-09-19/'},
    3: {'headline': 'SCU men\'s basketball team once snapped Gonzaga\'s 50-game home winning streak', 'url': 'https://en.wikipedia.org/wiki/Santa_Clara_Broncos'}, # Wikipedia URL kept (specific historical fact source)
    4: {'headline': 'Top seeds Mostafa Asal and Paul Coll reach U.S. Open men\'s final', 'url': 'https://thesquashsite.com/u-s-open-2025'},
    5: {'headline': 'Americans Increasingly Turn to Chatbots for Romantic Pursuits, Study Finds', 'url': 'https://www.newsweek.com/third-americans-have-had-romantic-relationship-ai-10814798'},
    6: {'headline': 'Carlos Alcaraz is youngest man in tennis history to win multiple majors on all surfaces', 'url': 'https://indianexpress.com/article/sports/tennis/roger-federer-carlos-alcaraz-serena-williams-10324761/'}, # Duplicate URL, but correct context
    7: {'headline': 'Did India “gift” an island to Myanmar? Untold story of Coco Islands', 'url': 'https://timesofindia.indiatimes.com/topic/andaman-and-nicobar-islands'}, # Topic page URL kept
    8: {'headline': 'SCU named No. 38 in Wall Street Journal \'2025 Best Colleges\'', 'url': 'https://www.scu.edu/news-and-events/press-releases/2025/september-2025/news/santa-clara-university-rises-to-59th-best-nationally-in-us-news--world-report-best-college-rankings.html'},
    9: {'headline': 'World #3 Amina Orfi survived 87-minute five-game duel with Nele Gilis', 'url': 'https://thesquashsite.com/u-s-open-2025'},
    10: {'headline': 'Minor volcanic eruptions noticed in Andaman\'s Barren Island', 'url': 'https://www.thehindu.com/news/national/andaman-and-nicobar-islands/'}, # Topic page URL kept
    11: {'headline': 'Amanda Sobhy wins \'Sobhy showdown\' against sister Sabrina', 'url': 'https://thesquashsite.com/u-s-open-2025'},
    12: {'headline': 'SIT inspects North Sentinel Island for any article left behind by arrested U.S. national', 'url': 'https://www.thehindu.com/news/national/andaman-and-nicobar-islands/'}, # Topic page URL kept
    13: {'headline': 'Harshit Rana\'s brilliant 4/39 helps restrict Australia to 236', 'url': 'https://timesofindia.indiatimes.com/sports/cricket/india-vs-australia/not-out-not-done-former-cricketers-hail-rohit-sharma-and-virat-kohli-after-vintage-odi-show-against-australia/articleshow/124812479.cms'}, # Duplicate URL, but correct context
    14: {'headline': 'Djokovic withdraws from Paris Masters', 'url': 'https://indianexpress.com/article/sports/tennis/novak-djokovics-paris-pullout-puts-focus-on-future-plans-10322611/'}, # Reused specific article URL
    15: {'headline': 'Santa Clara University Broncos compete at NCAA Division I level', 'url': 'https://en.wikipedia.org/wiki/Santa_Clara_University'}, # Wikipedia URL kept
    16: {'headline': 'Oil India discovers natural gas in Andaman shallow offshore block', 'url': 'https://www.thehindu.com/news/national/andaman-and-nicobar-islands/oil-india-discovers-natural-gas-in-andaman-shallow-offshore-block/article70101169.ece'},
    50: {'headline': 'Rohit Sharma slams unbeaten 121, reaches 50th international century', 'url': 'https://timesofindia.indiatimes.com/sports/cricket/india-vs-australia/not-out-not-done-former-cricketers-hail-rohit-sharma-and-virat-kohli-after-vintage-odi-show-against-australia/articleshow/124812479.cms'} # Duplicate URL, but correct context
}


# Load the data into a pandas DataFrame
# The 'id' column (1-50) will be the DataFrame's index
headlines_df = pd.DataFrame.from_dict(headline_data, orient='index')
headlines_df.index.name = 'id'

print("Headline data loaded into DataFrame. First 5 rows:")
print(headlines_df.head())

# %% [markdown]
# # Question 1
# Your first task is to convert the 50 text headlines into numerical embedding vectors. Initialize a SentenceTransformer model. For this lab, use the bert-base-uncased model. Use the model's .encode() method to generate embeddings for all 50 headlines in the headlines_df['headline'] column.Use the model's .encode() method to generate embeddings for all 50 headlines in the headlines_df['headline'] column. Store these embeddings in a NumPy array named headline_embeddings. Print the shape of your headline_embeddings array. & print the complete embedding vector for the first ten headlines.

# %% [markdown]
# # Question 2
# Now, let's compare all 50 headlines to each other.
# - Compute the Cosine Similarity matrix for all 50 embeddings. Use sklearn.metrics.pairwise.cosine_similarity on your headline_embeddings array. Store the result in a variable called cosine_matrix.
# - Compute the Dot Product matrix for all 50 embeddings. You can do this efficiently using numpy.dot() with your headline_embeddings array and its transpose. Store the result in dot_product_matrix.
# - Print the shape of both cosine_matrix and dot_product_matrix.
# - To "output the matrix" without printing the full 50x50 grid, print the first 5x5 slice of your cosine_matrix (i.e., the similarity scores for articles 1-5 against articles 1-5) and your dot_product_matrix.
# - Which of the 2 values (cosine, dot_product) is better suited to assessing article similarity in this scenario?

# %% [markdown]
# # Question 3
# A 50x50 matrix of numbers is hard to "eyeball." A heatmap is much better.
# - Use matplotlib.pyplot.imshow() to visualize your cosine_matrix. Include plt.colorbar() to show the scale. Explain what the bright squares and dark squares on your plot represent in terms of the article headlines.
# - Based on "eyeballing" your heatmap, identify two distinct groups of 3-4 articles that appear to be highly similar to each other (i.e., they form a bright square). List the article IDs (from 1 to 50) for each of your two groups. (e.g., "Group 1: [12, 13, 14], Group 2: [22, 23, 24]").

# %% [markdown]
# # Question 4
# Let's use a formal clustering algorithm to find the groups.  AgglomerativeClustering requires a distance (dissimilarity) matrix, not a similarity matrix. A high cosine score (like 0.9) means high similarity, but this corresponds to a low distance.
# - Create a new distance_matrix by calculating 1 - cosine_matrix. Ensure to execute this line of code after doing so to ensure the subsequent steps work as desired:
# np.fill_diagonal(distance_matrix, 0)
# - Instantiate and fit an AgglomerativeClustering model. In order to do this with precomputed dissimilarities, use the following parameters:
#   - metric='precomputed' (Scikit-learn 1.4+).
#   - If you have an older version, use affinity='precomputed'. * linkage='average' (Note: 'ward' linkage only works with Euclidean distance, not a precomputed matrix).
#   - Fit your model to the distance_matrix.
# - Visualize the dendrogram and output it.
# - What are the relative heights of articles within the same cluster and when the dendrogram cuts across clusters? What can you say about the strength and quality of these embeddings based on this?
# - Draw the cut-line at y=0.4. How many clusters emerge? Can you identify their topics/themes?
# - Look at the cluster assignments from Q4 for the two manual groups you identified in Q3. Did the AgglomerativeClustering algorithm generally place your manually-identified articles into the same cluster?

# %% [markdown]
# # Question 5
# Compare the Normalizer sample processor concept to Cosine_Sim and Dot_Products. Which one is Normalizer closer to and why?
